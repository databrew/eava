# %%
import pandas as pd
from pycrossva.transform import transform

# %%
input_data = pd.read_csv("va-data/VA_Data_Gambia_Site_31Oct2017/BS_HDSS/csv/gambia_child_WHO2016.csv")
input_data
# Out:
#                  dssid  -Id10004           -Id10007  -Id10008  -Id10009  \
# 0       8l010020801120       2.0   Halimatou Jallow         1       1.0
# 1       81o23040101110       2.0      Amie Sankareh         1       1.0
# 2      8101 0010401097       2.0   Hulaimatou Damba         4       1.0
# 3    8101 010121201122       2.0       Nana Bangura         1       1.0
# 4         800506708027       2.0  Adama  Hawa  Sowe         3       1.0
# ..                 ...       ...                ...       ...       ...
# 572    800492902030061       2.0         Kumba Sarr         4       1.0
# 573    800664010101038       2.0    Fatoumata  Suko         1       1.0
# 574    801010190101129       2.0     Satang Sanyang         4       1.0
# 575   8101010001001070       2.0        Assa Kanteh         1       1.0
# 576  80049250550101000       2.0     Eliyasa Jallow         4       1.0
#
#                   -Id10010  -Id10011   -Id10012  -Id10013        -Id10017  \
# ...

# %%
final_data = transform(("2016WHOv141", "InterVA5"), input_data)
# Out:
# Validating Mapping Configuration . . .
#
#  WARNINGS
# [?] 	 1 new column(s) listed but not defined in Mapping Configuration detected. These ('i358a') will be treated as NA.
# /home/mbr/miniconda3/envs/regnagrok/lib/python3.8/site-packages/pycrossva/configuration.py:513: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.prepared_data[mapping_condition.source_dtype] = \
# Validating Mapping-Data Relationship . . .
#
#  WARNINGS
# [?] 	 126 (41.0%) expected source column IDs listed in mapping file ('-ageInYears', '-age_adult', '-age_group', '-ageInDays', '-isNeonatal2', '-isNeonatal1', '-isNeonatal', '-ID10022', '-displayAgeNeonate', '-Id10059', etc) were not found in the input data columns. Their values will be NA.
# ...

# %%
final_data
# Out:
#     i004a i004b i019a i019b i022a i022b i022c i022d i022e i022f  ... i450o  \
# 0       n     n     n     n     .     .     .     .     .     .  ...     n
# 1       n     n     n     n     .     .     .     .     .     .  ...     n
# 2       n     n     n     n     .     .     .     .     .     .  ...     n
# 3       n     n     n     n     .     .     .     .     .     .  ...     n
# 4       n     n     n     n     .     .     .     .     .     .  ...     n
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 572     n     n     n     n     .     .     .     .     .     .  ...     n
# 573     n     n     n     n     .     .     .     .     .     .  ...     n
# 574     n     n     n     n     .     .     .     .     .     .  ...     n
# 575     n     n     n     n     .     .     .     .     .     .  ...     n
# 576     n     n     n     n     .     .     .     .     .     .  ...     n
#
#     i451o i452o i453o i454o i455o i456o i457o i458o i459o
# ...

# %%
final_data.to_csv("va-data/VA_Data_Gambia_Site_31Oct2017/BS_HDSS/csv/gambia_child_pyCrossVA.csv")
